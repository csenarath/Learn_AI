# %%
print("01_learned to use .env file to hide sensitive information like API keys.")
# Out:
# 01_learned to use .env file to hide sensitive information like API keys.

# %%
# %pip install langchain-anthropic
# Out:
# Collecting langchain-anthropic
#   Downloading langchain_anthropic-1.3.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: anthropic<1.0.0,>=0.75.0 in c:\users\chandimass\appdata\local\miniconda3\envs\learn_01\lib\site-packages (from langchain-anthropic) (0.76.0)
# Collecting langchain-core<2.0.0,>=1.2.6 (from langchain-anthropic)
#   Using cached langchain_core-1.2.7-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\chandimass\appdata\local\miniconda3\envs\learn_01\lib\site-packages (from langchain-anthropic) (2.12.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\chandimass\appdata\local\miniconda3\envs\learn_01\lib\site-packages (from anthropic<1.0.0,>=0.75.0->langchain-anthropic) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\chandimass\appdata\local\miniconda3\envs\learn_01\lib\site-packages (from anthropic<1.0.0,>=0.75.0->langchain-anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\users\chandimass\appdata\local\miniconda3\envs\learn_01\lib\site-packages (from anthropic<1.0.0,>=0.75.0->langchain-anthropic) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\chandimass\appdata\local\miniconda3\envs\learn_01\lib\site-packages (from anthropic<1.0.0,>=0.75.0->langchain-anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\chandimass\appdata\local\miniconda3\envs\learn_01\lib\site-packages (from anthropic<1.0.0,>=0.75.0->langchain-anthropic) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\chandimass\appdata\local\miniconda3\envs\learn_01\lib\site-packages (from anthropic<1.0.0,>=0.75.0->langchain-anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\chandimass\appdata\local\miniconda3\envs\learn_01\lib\site-packages (from anthropic<1.0.0,>=0.75.0->langchain-anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\chandimass\appdata\local\miniconda3\envs\learn_01\lib\site-packages (from anyio<5,>=3.5.0->anthropic<1.0.0,>=0.75.0->langchain-anthropic) (3.11)
# Requirement already satisfied: certifi in c:\users\chandimass\appdata\local\miniconda3\envs\learn_01\lib\site-packages (from httpx<1,>=0.25.0->anthropic<1.0.0,>=0.75.0->langchain-anthropic) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\chandimass\appdata\local\miniconda3\envs\learn_01\lib\site-packages (from httpx<1,>=0.25.0->anthropic<1.0.0,>=0.75.0->langchain-anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\chandimass\appdata\local\miniconda3\envs\learn_01\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic<1.0.0,>=0.75.0->langchain-anthropic) (0.16.0)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.2.6->langchain-anthropic)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.6->langchain-anthropic)
#   Using cached langsmith-0.6.6-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\chandimass\appdata\local\miniconda3\envs\learn_01\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain-anthropic) (25.0)
# Collecting pyyaml<7.0.0,>=5.3.0 (from langchain-core<2.0.0,>=1.2.6->langchain-anthropic)
#   Downloading pyyaml-6.0.3-cp312-cp312-win_amd64.whl.metadata (2.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.2.6->langchain-anthropic)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.6->langchain-anthropic)
#   Using cached uuid_utils-0.14.0-cp39-abi3-win_amd64.whl.metadata (5.0 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.6->langchain-anthropic)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain-anthropic)
#   Downloading orjson-3.11.5-cp312-cp312-win_amd64.whl.metadata (42 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain-anthropic)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting requests>=2.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain-anthropic)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain-anthropic)
#   Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\chandimass\appdata\local\miniconda3\envs\learn_01\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\chandimass\appdata\local\miniconda3\envs\learn_01\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\chandimass\appdata\local\miniconda3\envs\learn_01\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (0.4.2)
# Collecting charset_normalizer<4,>=2 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain-anthropic)
#   Downloading charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl.metadata (38 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain-anthropic)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Downloading langchain_anthropic-1.3.1-py3-none-any.whl (46 kB)
# Using cached langchain_core-1.2.7-py3-none-any.whl (490 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langsmith-0.6.6-py3-none-any.whl (308 kB)
# Downloading pyyaml-6.0.3-cp312-cp312-win_amd64.whl (154 kB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached uuid_utils-0.14.0-cp39-abi3-win_amd64.whl (182 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading orjson-3.11.5-cp312-cp312-win_amd64.whl (133 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl (107 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, uuid-utils, urllib3, tenacity, pyyaml, orjson, jsonpointer, charset_normalizer, requests, jsonpatch, requests-toolbelt, langsmith, langchain-core, langchain-anthropic
#
#    -- -------------------------------------  1/14 [uuid-utils]
#    ----- ----------------------------------  2/14 [urllib3]
#    ----- ----------------------------------  2/14 [urllib3]
#    ----- ----------------------------------  2/14 [urllib3]
#    ----- ----------------------------------  2/14 [urllib3]
#    ----- ----------------------------------  2/14 [urllib3]
#    ----- ----------------------------------  2/14 [urllib3]
#    ----- ----------------------------------  2/14 [urllib3]
#    ----- ----------------------------------  2/14 [urllib3]
#    -------- -------------------------------  3/14 [tenacity]
#    -------- -------------------------------  3/14 [tenacity]
#    -------- -------------------------------  3/14 [tenacity]
#    ----------- ----------------------------  4/14 [pyyaml]
#    ----------- ----------------------------  4/14 [pyyaml]
#    ----------- ----------------------------  4/14 [pyyaml]
#    ----------- ----------------------------  4/14 [pyyaml]
#    ----------------- ----------------------  6/14 [jsonpointer]
#    -------------------- -------------------  7/14 [charset_normalizer]
#    -------------------- -------------------  7/14 [charset_normalizer]
#    -------------------- -------------------  7/14 [charset_normalizer]
#    ---------------------- -----------------  8/14 [requests]
#    ---------------------- -----------------  8/14 [requests]
#    ---------------------- -----------------  8/14 [requests]
#    ---------------------- -----------------  8/14 [requests]
#    ------------------------- --------------  9/14 [jsonpatch]
#    ---------------------------- ----------- 10/14 [requests-toolbelt]
#    ---------------------------- ----------- 10/14 [requests-toolbelt]
#    ---------------------------- ----------- 10/14 [requests-toolbelt]
#    ---------------------------- ----------- 10/14 [requests-toolbelt]
#    ---------------------------- ----------- 10/14 [requests-toolbelt]
#    ---------------------------- ----------- 10/14 [requests-toolbelt]
#    ---------------------------- ----------- 10/14 [requests-toolbelt]
#    ------------------------------- -------- 11/14 [langsmith]
#    ------------------------------- -------- 11/14 [langsmith]
#    ------------------------------- -------- 11/14 [langsmith]
#    ------------------------------- -------- 11/14 [langsmith]
#    ------------------------------- -------- 11/14 [langsmith]
#    ------------------------------- -------- 11/14 [langsmith]
#    ------------------------------- -------- 11/14 [langsmith]
#    ------------------------------- -------- 11/14 [langsmith]
#    ------------------------------- -------- 11/14 [langsmith]
#    ------------------------------- -------- 11/14 [langsmith]
#    ------------------------------- -------- 11/14 [langsmith]
#    ------------------------------- -------- 11/14 [langsmith]
#    ------------------------------- -------- 11/14 [langsmith]
#    ------------------------------- -------- 11/14 [langsmith]
#    ------------------------------- -------- 11/14 [langsmith]
#    ------------------------------- -------- 11/14 [langsmith]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ---------------------------------- ----- 12/14 [langchain-core]
#    ------------------------------------- -- 13/14 [langchain-anthropic]
#    ------------------------------------- -- 13/14 [langchain-anthropic]
#    ------------------------------------- -- 13/14 [langchain-anthropic]
#    ---------------------------------------- 14/14 [langchain-anthropic]
#
# Successfully installed charset_normalizer-3.4.4 jsonpatch-1.33 jsonpointer-3.0.0 langchain-anthropic-1.3.1 langchain-core-1.2.7 langsmith-0.6.6 orjson-3.11.5 pyyaml-6.0.3 requests-2.32.5 requests-toolbelt-1.0.0 tenacity-9.1.2 urllib3-2.6.3 uuid-utils-0.14.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
from langchain_anthropic import ChatAnthropic

# Load environment variables from .env file
load_dotenv()

# Get API key from environment
API_KEY = os.getenv("API_KEY")

# Create LangChain Claude client
llm = ChatAnthropic(
    model="claude-sonnet-4-5",
    api_key=API_KEY,
    max_tokens=1024
)

# %%
# Make a sample API call using LangChain
response = llm.invoke("tell fun fact")

print(response.content)
# Out:
# Here's a fun fact:
#
# **Honey never spoils!** Archaeologists have found 3,000-year-old jars of honey in ancient Egyptian tombs that were still perfectly edible. Honey's low moisture content and acidic pH create an inhospitable environment for bacteria and microorganisms, making it essentially immortal. 🍯
