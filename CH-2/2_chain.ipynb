# %%
import os
from dotenv import load_dotenv
from langchain_anthropic import ChatAnthropic
from langchain_core.output_parsers import StrOutputParser


load_dotenv()
API_KEY = os.getenv("API_KEY")

from langchain_core.prompts import PromptTemplate ,ChatPromptTemplate

# %%
#chain with custom funtions

# %%
#Task 1 Prompt

prompt_template = ChatPromptTemplate.from_messages(
    [
       ("system", "You are a helpful assistant that is boomer" ),
       ("human", "{input}" )
    ]
)

# %%
#Task 2 LLM

llm_anthropic = ChatAnthropic(
    model="claude-sonnet-4-5",
    api_key=API_KEY,
    max_tokens=1024
)

# %%
#Task 3 STRPaser
str_parser=StrOutputParser()

# %%
#Task 4 [Custom Runnable]
from langchain_core.runnables import RunnableLambda

def dict_maker(text:str)-> dict:
    return {"text":text}

dict_maker_runnable = RunnableLambda(dict_maker)

# %%
#Task -5 [template for Post]

prompt_post = ChatPromptTemplate.from_messages(
    [
       ("system", "You are a news paper repoter for facebook" ),
       ("human", "create a post regarding folowing {input}" )
    ]
)

# %%
#chain

# %%
chain = prompt_template | llm_anthropic | str_parser | dict_maker_runnable  | llm_anthropic | str_parser

chain.invoke({"input": "what is your war story"})
